# %% [markdown]
# # 1️⃣1️⃣ Articles in the Nominative (Teil 1)
#
# ## Learning Objectives
#
# - What is **Nominativ**? (answers the questions: *Wer?* / *Was?*)
# - What is a **Substantiv** (noun)?
# - Types of articles
# - Definite article (bestimmter Artikel)
#
# ---
#
# # What is Nominative?
#
# ✔ The **Nominative** is the **subject** of the sentence.
# ✔ The subject answers: **Wer? (Who?)** or **Was? (What?)**
#
# ### Sentence Structure
#
# Satz = **Subjekt (Nominativ) + Verb**
#
# Example:
#
# - Sabine ist ledig.
# - Das Haus ist groß.
#
# ---
#
# # Subject (Subjekt)
#
# The subject can be:
#
# - **Nomen** (noun)
# - **Pronomen** (pronoun)
#
# ---
#
# # Nomen (Substantiv)
#
# A noun can be:
#
# - **Person**
# - **Sache** (thing)
#
# Examples:
#
# ### Person
# - Wer ist das?
#   → Das ist Peter.
#
# ### Sache
# - Was ist das?
#   → Das ist ein Bus.
#
# ---
#
# # Types of Articles
#
# - bestimmter Artikel (definite article)
# - unbestimmter Artikel (indefinite article)
# - Negationsartikel (negative article)
#
# ---
#
# # Definite Articles in Nominative
#
# ## Singular
#
# | Gender      | Article |
# |-------------|----------|
# | maskulin    | der |
# | feminin     | die |
# | neutrum     | das |
#
# ## Plural (all genders)
#
# | Plural |
# |--------|
# | die |
#
# ---
#
# # Examples
#
# | Singular | Plural |
# |----------|----------|
# | der Mann | die Männer |
# | die Frau | die Frauen |
# | das Baby | die Babys |
#
# ---
#
# # Quick Recognition Trick
#
# Often the noun endings help:
#
# - **der Mann**
# - **die Frau**
# - **das Baby**
#
# But ⚠️ always learn nouns with their article.
